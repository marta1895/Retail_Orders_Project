# %%
# !pip install opendatasets --upgrade
# Out:
# Requirement already satisfied: opendatasets in ./py312/lib/python3.9/site-packages (0.1.22)
# Requirement already satisfied: tqdm in ./py312/lib/python3.9/site-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in ./py312/lib/python3.9/site-packages (from opendatasets) (1.7.4.5)
# Requirement already satisfied: click in ./py312/lib/python3.9/site-packages (from opendatasets) (8.1.8)
# Requirement already satisfied: bleach in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (2026.1.4)
# Requirement already satisfied: charset-normalizer in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (3.4.4)
# Requirement already satisfied: idna in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (3.11)
# Requirement already satisfied: protobuf in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (6.33.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (58.0.4)
# Requirement already satisfied: six>=1.10 in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (2.6.3)
# Requirement already satisfied: webencodings in ./py312/lib/python3.9/site-packages (from kaggle->opendatasets) (0.5.1)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./py312/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in ./py312/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./py312/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./py312/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./py312/lib/python3.9/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in ./py312/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import opendatasets as od
import pandas as pd

od.download("https://www.kaggle.com/datasets/ankitbansal06/retail-orders")
# Out:
# Skipping, found downloaded files in "./retail-orders" (use force=True to force download)

# %%
df = pd.read_csv("retail-orders/orders.csv")
df.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    Discount Percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
# Define common representations of missing values
# Covers case differences, system-generated placeholders,
# and human-entered empty or invalid values
na_vals = [
    'Not Available', 'not available',
    'Unknown', 'unknown',
    'N/A', 'NA', 'n/a',
    '', ' '
]

# Read CSV file and standardize missing values to NaN
# keep_default_na=True preserves pandas' default missing value detection
df = pd.read_csv(
    "retail-orders/orders.csv",
    na_values=na_vals,
    keep_default_na=True
)

# %%
df.isna().sum().sort_values(ascending=False) 
#First, isna() identifies missing values in the dataset.
#Then, sum() calculates the total number of missing values for each column.
#Finally, sort_values() orders the columns by the number of missing values in descending order.
# Out:
# Ship Mode           6
# Order Id            0
# Order Date          0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
# Convert all column names to lowercase
df.columns = df.columns.str.lower()

# Replace spaces in column names with underscores
df.columns = df.columns.str.replace(' ', '_')

df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    discount_percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          9994 non-null   int64
#  1   order_date        9994 non-null   object
#  2   ship_mode         9988 non-null   object
#  3   segment           9994 non-null   object
#  4   country           9994 non-null   object
#  5   city              9994 non-null   object
#  6   state             9994 non-null   object
#  7   postal_code       9994 non-null   int64
#  8   region            9994 non-null   object
#  9   category          9994 non-null   object
#  10  sub_category      9994 non-null   object
#  11  product_id        9994 non-null   object
#  12  cost_price        9994 non-null   int64
#  13  list_price        9994 non-null   int64
#  14  quantity          9994 non-null   int64
#  15  discount_percent  9994 non-null   int64
# dtypes: int64(6), object(10)
# memory usage: 1.2+ MB

# %%
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# %%
df['order_id'].is_unique #Check uniqueness
# Out:
# True

# %%
df['order_id'].isna().sum() #Check missing values
# Out:
# np.int64(0)

# %%
df.shape[0] == df['order_id'].nunique() #Check row count vs unique count
# Out:
# True

# %%
# Calculate discount amount per order
df['discount'] = df['list_price'] * df['discount_percent'] / 100

# Calculate sale price after discount
df['sale_price'] = df['list_price'] - df['discount']

# Calculate profit per order
df['profit'] = df['sale_price'] - df['cost_price']

df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    discount_percent  discount  sale_price  profit
# 0                 2       5.2       254.8    14.8
# 1                 3      21.9       708.1   108.1
# 2                 5       0.5         9.5    -0.5
# 3                 2      19.2       940.8   160.8
# 4                 5       1.0        19.0    -1.0

# %%
# Remove original pricing columns after deriving required metrics
# This simplifies the dataset while preserving pricing information
df.drop(
    columns=['cost_price', 'list_price', 'discount_percent'],
    inplace=True
)

df.head(10)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
# 5         6 2022-03-13             NaN   Consumer  United States
# 6         7 2022-12-28  Standard Class   Consumer  United States
# 7         8 2022-01-25  Standard Class   Consumer  United States
# 8         9 2023-03-23             NaN   Consumer  United States
# 9        10 2023-05-16  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
# 5      Los Angeles  California        90032   West        Furniture
# 6      Los Angeles  California        90032   West  Office Supplies
# 7      Los Angeles  California        90032   West       Technology
# 8      Los Angeles  California        90032   West  Office Supplies
# 9      Los Angeles  California        90032   West  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# 1       Chairs  FUR-CH-10000454         3      21.9       708.1   108.1
# 2       Labels  OFF-LA-10000240         2       0.5         9.5    -0.5
# 3       Tables  FUR-TA-10000577         5      19.2       940.8   160.8
# 4      Storage  OFF-ST-10000760         2       1.0        19.0    -1.0
# 5  Furnishings  FUR-FU-10001487         7       1.5        48.5    -1.5
# 6          Art  OFF-AR-10002833         4       0.3         9.7    -0.3
# 7       Phones  TEC-PH-10002275         6      45.5       864.5     4.5
# 8      Binders  OFF-BI-10003910         3       0.4        19.6    -0.4
# 9   Appliances  OFF-AP-10002892         5       3.3       106.7    16.7

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in ./py312/lib/python3.9/site-packages (2.0.45)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./py312/lib/python3.9/site-packages (from sqlalchemy) (4.15.0)

# %%
import sqlalchemy as sal

db_username = 'postgres'
db_password = '1212'
db_host = 'localhost'
db_port = '5433'
db_name = 'postgres'

connection_string = (
    f'postgresql+psycopg2://{db_username}:{db_password}'
    f'@{db_host}:{db_port}/{db_name}'
)

engine = sal.create_engine(connection_string)
conn = engine.connect()

# %%
#Load the data into SQL server using replace function
df.to_sql('df_orders', con=conn, index=False, if_exists = 'append')
# Out:
# 994
